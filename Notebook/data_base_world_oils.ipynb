# %%
# !pip install pandas
# !pip install openpyxl

# %%
# pandas
import pandas as pd

tabela = pd.read_excel("data_base.xlsx")
display(tabela)
# Out:
#                                          Unnamed: 0   Peters et al., 2005  \
# 0                                               NaN     Geological origen
# 1                                               NaN               Samples
# 2                                     OilMod Ratios               C19/C23
# 3                                               NaN               C22/C21
# 4                                               NaN               C24/C23
# 5                                               NaN               C26/C25
# 6                                               NaN               Tet/C23
# 7                                               NaN              C27T/C27
# 8                                               NaN                 C28/H
# 9                                               NaN                 C29/H
# 10                                              NaN                C30X/H
# 11                                              NaN                  OL/H
# ...
